# %%
import ecoinvent_interface as ei

# %%
my_settings = ei.Settings()
ep = ei.EcoinventProcess(my_settings)

# %%
ep.set_release(version="3.10.1", system_model="EN15804")

# %%
ep.select_process(dataset_id="1")

# %%
ep.get_basic_info()
# Out:
# {'index': 1,
#  'version': '3.10.1',
#  'system_model': 'EN15804',
#  'activity_name': 'electricity production, nuclear, boiling water reactor',
#  'geography': {'comment': None, 'short_name': 'FI', 'long_name': 'Finland'},
#  'reference_product': 'electricity, high voltage',
#  'has_access': True,
#  'unit': 'kWh',
#  'sector': 'Electricity'}

# %%
ep.get_methods()
# Out:
# [{'method_id': 884, 'method_name': 'EF v3.0 EN15804'},
#  {'method_id': 1466, 'method_name': 'EF v3.1 EN15804'},
#  {'method_id': 995, 'method_name': 'EN15804'},
#  {'method_id': 1043, 'method_name': 'TRACI v2.1'}]

# %%
ep.get_documentation()
# Out:
# {'id': 'b3522134-40fe-53fc-9ef5-18d99ccb4434',
#  'activity_description': {'name': 'electricity production, nuclear, boiling water reactor',
#   'general_comment': 'This dataset represents the production of high voltage electricity at a grid-connected nuclear boiling water reactor (BWR) in Finland in 2012.\n\nIt is a copy of the dataset "electricity production, nuclear, boiling water reactor, CH, 1995-2002", i.e. of a dataset with data for a Swiss nuclear BWR. The basic source for all exchanges is therefore the ecoinvent report "Kernenergie" (see Modelling and Administrative). Data of this CH dataset are scaled with a factor derived from the comparison of the efficiencies of Swiss BWR and those valid for this dataset in order to account for a higher or lower fuel input for the production of 1 kWh, respectively.\n\nThe average burnup 48.6 MWd/kg heavy metal of finally discharged fuel elements from the 2000/2002 fuel cycles has been assumed representative for the lifetime of the modeled plant (the burnup has increased from the initial about 33 MWd/kg heavy metal and may increase to 55 MWd/kg heavy metal in the future). The average burnup corresponds to an average enrichment of 3.8% U235 for fresh uranium fuel elements. For the calculation of the total net electricity delivered in 40 years lifetime, the sum of the actual production till 2002 and the prospective (9000 GWh/a) till end of life using  is considered; this gives 3.46E11 kWh; the inverse gives the utilisation factor for the infrastructure. Full detailed information on material requirements during operation for 1991/1992 are available. The diesel requirements for the yearly test of diesel emergency generators are accounted for. Radioactive emission species to air and water are weighted averages of the emissions of the nuclear power plants Leibstadt and Mühleberg (CH) from 1995 to 2002. Alpha aerosols emission to air have been described with "aerosols, unspecified". Considered radioactive waste streams are: spent fuel to reprocessing (40%) and conditioning (60%); operational low active waste for conditioning in the intermediate repository; and, contaminated waste from dismantling.\n\n[This dataset is meant to replace the following datasets:]',
#   'product_information': 'This product represents electrical energy measured in kWh. If electricity is taken from a market for electricity, the transmission infrastructure, country-specific losses and transformation losses (for markets for medium and low voltage) are included. Covers voltages above 24 kV. ',
#   'synonyms': ['BWR'],
#   'geography': {'comment': 'Extrapolated from Swiss data of one specific plant for requirements and all Swiss BWRs for emissions.',
#    'short_name': 'FI',
#    'long_name': ''},
#   'special_activity_type': 0,
#   'time_period': '1990-2023',
#   'technology': {'comment': 'Best current technology for fuel element. Standard technology for commercial operation.',
#    'technology_level': 2},
#   'time_period_comment': 'The Annual Production Volume is valid for the year 2012. ',
#   'included_activities_start': 'From the constructed power plant ready to produce electricity and from the fuel ready in the power plant.',
#   'included_activities_end': 'This activity ends with 1kWh of high voltage electricity produced at the power plant and arrived at the busbar.\nThe module includes fuel elements, chemicals, and diesel requirements as well as the relevant transport requirements. Water use (fresh and decarbonized) for cooling is included. Considered radioactive waste streams are: spent fuel to reprocessing and conditioning; operational low active waste for conditioning in the intermediate repository; and, contaminated waste from dismantling. Non-radioactive wastes are accounted for.\n\nThe module includes fuel elements, chemicals, and diesel requirements as well as the relevant transport requirements. Water use (fresh and decarbonized) for cooling is included, but no cooling tower infrastructure. Considered radioactive waste streams are: spent fuel to reprocessing and conditioning; operational low active waste for conditioning in the intermediate repository; and, contaminated waste from dismantling. Non-radioactive wastes are accounted for.'},
#  'modelling_and_validation': {'reviews': [{'review_date': '2015-06-01',
#     'reviewer_id': 'c4597934-ecac-422c-b431-382e85fdcb83',
#     'reviewer_name': '[System]',
#     'reviewer_email': 'support@ecoinvent.org',
#     'reviewed_major_release': 3,
#     'reviewed_minor_release': 2,
#     'reviewed_major_revision': 1,
#     'reviewed_minor_revision': 155,
#     'comments': None},
#    {'review_date': '2021-01-16',
#     'reviewer_id': '847a56f5-d9e5-4a65-ab51-b056e0039130',
#     'reviewer_name': 'Avraam Symeonidis',
#     'reviewer_email': 'Symeonidis@ecoinvent.org',
#     'reviewed_major_release': 3,
#     'reviewed_minor_release': 0,
#     'reviewed_major_revision': 1,
#     'reviewed_minor_revision': 2,
#     'comments': None},
#    {'review_date': '2021-01-16',
#     'reviewer_id': 'c4597934-ecac-422c-b431-382e85fdcb83',
#     'reviewer_name': '[System]',
#     'reviewer_email': 'support@ecoinvent.org',
#     'reviewed_major_release': 3,
#     'reviewed_minor_release': 0,
#     'reviewed_major_revision': 0,
#     'reviewed_minor_revision': 3,
#     'comments': None},
#    {'review_date': '2021-01-16',
#     'reviewer_id': 'c4597934-ecac-422c-b431-382e85fdcb83',
#     'reviewer_name': '[System]',
#     'reviewer_email': 'support@ecoinvent.org',
#     'reviewed_major_release': 3,
#     'reviewed_minor_release': 0,
#     'reviewed_major_revision': 1,
#     'reviewed_minor_revision': 2,
#     'comments': None}],
#   'representativeness': {'sampling_procedure': 'Literature, statistics, and information from operators.',
#    'extrapolations': 'This datasets is taken over from a dataset valid for Switzerland (CH). Data quality for this Swiss dataset is high. Geographical uncertainty has been adjusted accordingly.\n\nThe Swiss dataset is valid for  1995-2002 and is partly based on older sources. Temporal uncertainty has been adjusted accordingly.',
#    'percent': None}},
#  'data_generator_and_publication': {'person_id': '610bd1b2-fec3-4e8e-84a6-76fef8b6b7b8',
#   'person_email': 'karin.treyer@psi.ch',
#   'person_name': 'Karin Treyer',
#   'access_restricted_to': 'LICENSEES',
#   'data_published_in': '2',
#   'published_source_year': '2007',
#   'published_source_first_author': 'Dones, R.',
#   'is_copyright_protected': True,
#   'page_numbers': None,
#   'additional_authors': None,
#   'title': 'Kernenergie',
#   'title_of_anthology': 'Sachbilanzen von Energiesystemen. Final report No. 6 ecoinvent data v2.0',
#   'place_of_publication': 'Dübendorf and Villigen, CH',
#   'source_publisher': 'Swiss Centre for LCI, PSI',
#   'source_volume_number': '6',
#   'source_type': '4'},
#  'administrative_information': {'data_entry_by': {'person_id': '610bd1b2-fec3-4e8e-84a6-76fef8b6b7b8',
#    'person_name': 'Karin Treyer',
#    'person_email': 'karin.treyer@psi.ch',
#    'is_active_author': True},
#   'file_attributes': {'file_timestamp': '2015-07-03T09:43:19',
#    'creation_timestamp': '2015-03-25T22:41:30',
#    'major_release': '3',
#    'minor_release': '0',
#    'major_revision': '5',
#    'minor_revision': '0'}}}

# %%
ep.get_related_datasets()
# Out:
# [{'spold_id': 6098,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity, high voltage, import from EE',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 6396,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity, high voltage, import from NO',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 7920,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity, high voltage, import from RU',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 460,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity, high voltage, import from SE',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 24825,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity, high voltage, production mix',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 25452,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity, high voltage, residual mix',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 5466,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, hard coal',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 8015,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, hydro, reservoir, non-alpine region',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 1374,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, hydro, run-of-river',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 12851,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, natural gas, combined cycle power plant',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 9754,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, natural gas, conventional power plant',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, nuclear, boiling water reactor',
#   'related_dataset_type': 'activity',
#   'is_current': True},
#  {'spold_id': 3075,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, nuclear, pressure water reactor',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 2574,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, oil',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 4104,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, peat',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 7769,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, wind, 1-3MW turbine, offshore',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 5383,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, wind, 1-3MW turbine, onshore',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 2248,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, wind, <1MW turbine, onshore',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 9913,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity production, wind, >3MW turbine, onshore',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 7838,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'heat and power co-generation, biogas, gas engine',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 12384,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'heat and power co-generation, hard coal',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 12711,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'heat and power co-generation, natural gas, combined cycle power plant, 400MW electrical',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 13425,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'heat and power co-generation, natural gas, conventional power plant, 100MW electrical',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 13365,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'heat and power co-generation, oil',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 1457,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 9758,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'market for electricity, high voltage',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 1966,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'treatment of blast furnace gas, in power plant',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 6916,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'treatment of coal gas, in power plant',
#   'related_dataset_type': 'activity',
#   'is_current': False},
#  {'spold_id': 351,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'CH',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 9278,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'DE',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 5579,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'ES',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'FI',
#   'related_dataset_type': 'geography',
#   'is_current': True},
#  {'spold_id': 13822,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'GB',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 16023,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'IN-MH',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 863,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'JP',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 7689,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'MX',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 7178,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'RoW',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 5288,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'RU',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 7659,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'SE',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 7706,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'TW',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 6046,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'US-MRO',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 9266,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'US-NPCC',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 2843,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'US-RFC',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 3202,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'US-SERC',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 6369,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'US-TRE',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 8785,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'US-WECC',
#   'related_dataset_type': 'geography',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'electricity, high voltage',
#   'related_dataset_type': 'product',
#   'is_current': True},
#  {'spold_id': 1,
#   'version': '3.11',
#   'system_model': 'EN15804',
#   'description': '3.11',
#   'related_dataset_type': 'version',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': '3.10.1',
#   'related_dataset_type': 'version',
#   'is_current': True},
#  {'spold_id': 1,
#   'version': '3.10',
#   'system_model': 'EN15804',
#   'description': '3.10',
#   'related_dataset_type': 'version',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.9.1',
#   'system_model': 'EN15804',
#   'description': '3.9.1',
#   'related_dataset_type': 'version',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.9',
#   'system_model': 'EN15804',
#   'description': '3.9',
#   'related_dataset_type': 'version',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.8',
#   'system_model': 'EN15804',
#   'description': '3.8',
#   'related_dataset_type': 'version',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'cutoff',
#   'description': 'cutoff',
#   'related_dataset_type': 'system_model',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'consequential',
#   'description': 'consequential',
#   'related_dataset_type': 'system_model',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'apos',
#   'description': 'apos',
#   'related_dataset_type': 'system_model',
#   'is_current': False},
#  {'spold_id': 1,
#   'version': '3.10.1',
#   'system_model': 'EN15804',
#   'description': 'EN15804',
#   'related_dataset_type': 'system_model',
#   'is_current': True},
#  {'spold_id': 83562,
#   'version': '3.10.1',
#   'system_model': 'undefined',
#   'description': 'undefined',
#   'related_dataset_type': 'system_model',
#   'is_current': False}]

# %%
ep.get_consuming_activities()
# Out:
# {'total': 3,
#  'consuming_activities': [{'activity_name': 'electricity, high voltage, production mix',
#    'geography': 'FI',
#    'reference_product': 'electricity, high voltage',
#    'amount': 0.25167315284424835,
#    'unit_name': 'kWh',
#    'spold_id': 24825},
#   {'activity_name': 'market for electricity, high voltage',
#    'geography': 'FI',
#    'reference_product': 'electricity, high voltage',
#    'amount': 0.181176890997018,
#    'unit_name': 'kWh',
#    'spold_id': 9758},
#   {'activity_name': 'electricity, high voltage, residual mix',
#    'geography': 'FI',
#    'reference_product': 'electricity, high voltage',
#    'amount': 0.0394520460545315,
#    'unit_name': 'kWh',
#    'spold_id': 25452}]}

# %%
ep.get_lci()

# %%
ep.get_exchanges()
# Out:
# {'intermediateExchange': [{'name': 'electricity, high voltage',
#    'group': 'Reference product',
#    'comment': '',
#    'uncertainty': None,
#    'property': [{'name': 'PENRE',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 14.059546515565454},
#     {'name': 'PENRM',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'PERE',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.017418838546154284},
#     {'name': 'PERM',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'biogenic carbon content in accompanying packaging',
#      'unit': 'kg C',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'biogenic carbon content in product',
#      'unit': 'kg C',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'price',
#      'unit': 'EUR2005',
#      'uncertainty': None,
#      'comment': 'Temporary price data. Calculated as 90% of purchasers price based on: 94% of the average price (to account for a 6% loss in transformation and transmission) for electricity for industrial consumersin 2005 (excluded taxes). From IEA.',
#      'amount': 0.0977}],
#    'amount': 1.0,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '17100: Electrical energy',
#     'HS2017': '271600: Electrical energy'},
#    'link': None,
#    'unit': 'kWh',
#    'productionVolumeComment': 'Literature value/statistics. For both OECD and non-OECD countries, gross electricity production 2012 with nuclear plants was taken from the IEA electricity information 2014, table 1.2. For a split of this total value into electricity production in different types of nuclear plants (boiling water reactor, pressure water reactor and pressurised heavy water reactor), data from IEAE 2014 (PRIS database) were exploited. An own electricity use of 6% (losses between gross and net electricity production) has been applied to the gross data based on IEA 2014.\n \nIEA. 2014. Electricity Information 2014. ISBN 978-92-64-21692-1. International Energy Agency (IEA), Paris Cedex (FR).\nIAEA. 2014. PRIS (Power Reactor Information System) - The database on nuclear power reactors. Country statistics. Online database. International Atomic Energy Agency.',
#    'productionVolumeAmount': 12617860135.559317},
#   {'name': 'acetylene',
#    'group': 'From technosphere',
#    'comment': 'Operator information',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 3.24e-08,
#      'mu': -17.245107414148126,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.923076923077},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.923076923077},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'C2H2. ecoinvent v2.2 report n 8. Produced from partial oxidation of natural gas',
#      'amount': 0.923076923077},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'C2H2. ecoinvent v2.2 report n 8. Produced from partial oxidation of natural gas',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'Based on literature, page 25 (Value may refer to HHV), Althaus H.-J., Chudacoff M., Hischier R., Jungbluth N., Osses M. and Primas A. (2007) Life Cycle Inventories of Chemicals. Final report ecoinvent data v2.0 No. 8. EMPA, Swiss Centre for Life Cycle Inventories, Dübendorf, CH, Online-Version under: www.ecoinvent.org.',
#      'amount': 51.2},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 3.24e-08,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34110: Hydrocarbons and their halogenated, sulphonated, nitrated or nitrosated derivatives',
#     'HS2017': '290129: Acyclic hydrocarbons; unsaturated, n.e.c. in heading no. 2901'},
#    'link': {'url': '17738',
#     'name': 'market for acetylene',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'anionic resin',
#    'group': 'From technosphere',
#    'comment': 'Operator information. All resin types needed are modeled as 50% anionic resin and 50% cationic resin.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.06e-06,
#      'mu': -13.757241649840298,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.340360440318},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.680720880636},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Cross-linked polystyrene beads are treated with chloromethyl methyl ether under anhydrous conditions, with either aluminum chloride or tin(IV) chloride as catalyst. Chloromethylated polystyrene is obtained. In a second stage, the chlorine in the chloromethylated group can be replaced by an amine (Anion exchange resins, in Ullmann). In this case, Trimethylamine, C3H9N, is used (ecoinvent v2.2 report 8-part 93). That is, the resine can be formulated as C12H18NCl (after Ullmann, Anion exchange resins). The resine is hydrated (ecoinvent v2.2 report 8, part II, Tab 93.7)',
#      'amount': 0.680720880636},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'resine is hydrated (ecoinvent v2.2 report 8, part II, Tab 93.7)',
#      'amount': 0.5},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'LHV is calculated based on the Carbon content of the product. More details can be found on the respective documentation.',
#      'amount': 9.09},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'resine is hydrated (ecoinvent v2.2 report 8, part II, Tab 93.7)',
#      'amount': 0.5},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.06e-06,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34790: Other plastics in primary forms; ion exchangers',
#     'HS2017': '390750: Alkyd resins; in primary forms'},
#    'link': {'url': '18488',
#     'name': 'market for anionic resin',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'argon, liquid',
#    'group': 'From technosphere',
#    'comment': 'Estimation. Gas use in the power plant. Argon and helium are summed up in this exchange',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 2.34e-05,
#      'mu': -10.662774535600619,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Ar 99.99%',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Ar 99.99%',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 2.34e-05,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34210: Hydrogen, nitrogen, oxygen, carbon dioxide and rare gases; inorganic oxygen compounds of non-metals n.e.c.',
#     'HS2017': '280421: Gases, rare; argon'},
#    'link': {'url': '18958',
#     'name': 'market for argon, liquid',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'borax, anhydrous, powder',
#    'group': 'From technosphere',
#    'comment': 'Operator information.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 2.89e-08,
#      'mu': -17.359424241828023,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Na2B4O7',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Na2B4O7',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 2.89e-08,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34270: Cyanides, cyanide oxides and complex cyanides; fulminates, cyanates and thiocyanates; silicates; borates; perb[…]',
#     'HS2017': '284011: Borates; disodium tetraborate (refined borax), anhydrous'},
#    'link': {'url': '5073',
#     'name': 'market for borax, anhydrous, powder',
#     'geography': 'GLO'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'boric acid, anhydrous, powder',
#    'group': 'From technosphere',
#    'comment': 'Operator information.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 2.31e-08,
#      'mu': -17.583433219418662,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'H3BO3',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'H3BO3',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 2.31e-08,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34270: Cyanides, cyanide oxides and complex cyanides; fulminates, cyanates and thiocyanates; silicates; borates; perb[…]',
#     'HS2017': '281000: Oxides of boron; boric acids'},
#    'link': {'url': '2292',
#     'name': 'market for boric acid, anhydrous, powder',
#     'geography': 'GLO'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'carbon dioxide, liquid',
#    'group': 'From technosphere',
#    'comment': 'Estimation. Gas use in the power plant.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.5e-07,
#      'mu': -15.712630542850155,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.272727272727},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.272727272727},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'CO2.',
#      'amount': 0.272727272727},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'CO2.',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'LHV is calculated based on the elemental composition of the substance. Based on the name of the substance, the formula is found manually.',
#      'amount': 8.27},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.5e-07,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34210: Hydrogen, nitrogen, oxygen, carbon dioxide and rare gases; inorganic oxygen compounds of non-metals n.e.c.',
#     'HS2017': '281121: Carbon dioxide'},
#    'link': {'url': '12080',
#     'name': 'market for carbon dioxide, liquid',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'cast iron',
#    'group': 'From technosphere',
#    'comment': 'Operator information',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.16e-07,
#      'mu': -15.969675645840047,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.04},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.04},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Cast iron is made by remelting pig iron in small furnaces (e.g. cupola furnaces or electric arc furnaces) and poured into moulds to make castings. It usually contains 2% to 6% carbon (ecoinvent v2.2 report 10_partII). An average content of 4% was considered',
#      'amount': 0.04},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'Non combustible products are assumed to have an LHV equal to zero (0).',
#      'amount': 0.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.16e-07,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '41111: Pig iron and spiegeleisen in pigs, blocks or other primary forms',
#     'HS2017': '7201: Pig iron and spiegeleisen in pigs, blocks or other primary forms'},
#    'link': {'url': '2023', 'name': 'market for cast iron', 'geography': 'GLO'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'cationic resin',
#    'group': 'From technosphere',
#    'comment': 'Operator information. All resin types needed are modeled as 50% anionic resin and 50% cationic resin.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.06e-06,
#      'mu': -13.757241649840298,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.260802932562},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.521605865124},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Chemically inert polystyrene beads are treated with concentrated sulfuric or chlorosulfonic acid to give cross-linked polystyrene 3-sulfonic acid (Cation exchange resins, Ullmann). The resine was approximated as C8H8O3S (from Ullmann, Cation exchange resins). The resine is hydrated (ecoinvent v2.2 report 8, part II, Tab 93.5)',
#      'amount': 0.521605865124},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'resine is hydrated (ecoinvent v2.2 report 8, part II, Tab 93.5)',
#      'amount': 0.5},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'LHV is calculated based on the Carbon content of the product. More details can be found on the respective documentation.',
#      'amount': 6.68},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'resine is hydrated (ecoinvent v2.2 report 8, part II, Tab 93.5)',
#      'amount': 0.5},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.06e-06,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34790: Other plastics in primary forms; ion exchangers',
#     'HS2017': '390799: Polyesters; n.e.c. in heading no. 3907, saturated, in primary forms'},
#    'link': {'url': '18700',
#     'name': 'market for cationic resin',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'cement, Portland',
#    'group': 'From technosphere',
#    'comment': 'Operator information. Cement use for conditioning of the hard waste.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 7.71e-06,
#      'mu': -11.772992370389035,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 7.71e-06,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '37440: Portland cement, aluminous cement, slag cement and similar hydraulic cements, except in the form of clinkers',
#     'HS2017': '252329: Cement; portland, other than white, whether or not artificially coloured'},
#    'link': {'url': '324',
#     'name': 'market for cement, Portland',
#     'geography': 'Europe without Switzerland'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'chemical, inorganic',
#    'group': 'From technosphere',
#    'comment': 'Operator information. Decontamination chemicals and salt for water softening.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 6.01e-07,
#      'mu': -14.324670902411203,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.003},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.003},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'This dataset is an unweighted average of 20 inorganic substances (listed in Tab 88.1, ecoinvent v2.2 report 8, part II), being part of the top100 chemicals included in this database. The C-content has also been calculated as an unweighted average of the C content of the substances composing this dataset.',
#      'amount': 0.003},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'This dataset is an unweighted average of 20 inorganic substances (listed in Tab 88.1, ecoinvent v2.2 report 8, part II), being part of the top100 chemicals included in this database. The C-content has also been calculated as an unweighted average of the C content of the substances composing this dataset.',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'Non combustible products are assumed to have an LHV equal to zero (0).',
#      'amount': 0.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 6.01e-07,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '342: Basic inorganic chemicals n.e.c.',
#     'HS2017': '28: Inorganic chemicals; organic and inorganic compounds of precious metals; of rare earth metals, of radio-active [...]'},
#    'link': {'url': '4588',
#     'name': 'market for chemical, inorganic',
#     'geography': 'GLO'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'chemical, organic',
#    'group': 'From technosphere',
#    'comment': 'Operator information. This category contains solvents, frost protection, anticorrosives, industrial alcohol, washing agents.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.24e-06,
#      'mu': -13.60039917834733,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.628},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.628},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'This dataset is an unweighted average of 20 organic substances (listed in Tab 88.1, ecoinvent v2.2 report 8, part II), being part of the top100 chemicals included in this database. The C-content has also been calculated as an unweighted average of the C content of the substances composing this dataset.',
#      'amount': 0.628},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'This dataset is an unweighted average of 20 organic substances (listed in Tab 88.1, ecoinvent v2.2 report 8, part II), being part of the top100 chemicals included in this database. The C-content has also been calculated as an unweighted average of the C content of the substances composing this dataset.',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'LHV is calculated based on the Carbon content of the product. More details can be found on the respective documentation.',
#      'amount': 19.03},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.24e-06,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '341: Basic organic chemicals',
#     'HS2017': '29: Organic chemicals'},
#    'link': {'url': '7063',
#     'name': 'market for chemical, organic',
#     'geography': 'GLO'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'concrete, normal strength',
#    'group': 'From technosphere',
#    'comment': 'Literature value',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.59e-08,
#      'mu': -17.956946727720226,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'cement and gravel. Tab 6.2, ecoinvent v2.2 report 7, part III',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'cement and gravel. Tab 6.2, ecoinvent v2.2 report 7, part III',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'wet mass-water mass',
#      'amount': 2190.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0867579908676},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'Tab 6.2, ecoinvent v2.2 report 7, part III',
#      'amount': 190.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'Tab 6.2, ecoinvent v2.2 report 7, part III',
#      'amount': 2380.0}],
#    'amount': 1.59e-08,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '37510: Non-refractory mortars and concretes',
#     'HS2017': '6810: Cement, concrete or artificial stone; whether or not reinforced, articles thereof'},
#    'link': {'url': '12483',
#     'name': 'market for concrete, normal strength',
#     'geography': 'RoW'},
#    'unit': 'm3',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'diesel, burned in diesel-electric generating set, 10MW',
#    'group': 'From technosphere',
#    'comment': 'Estimation. Diesel use for testing of the emergency power in the power plant.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.000333,
#      'mu': -8.00736806798383,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.000333,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '17100: Electrical energy'},
#    'link': {'url': '6946',
#     'name': 'market for diesel, burned in diesel-electric generating set, 10MW',
#     'geography': 'GLO'},
#    'unit': 'MJ',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'flat glass, coated',
#    'group': 'From technosphere',
#    'comment': 'Operator information. Materials for sand blasting equipment.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 3.93e-06,
#      'mu': -12.446871132083105,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Tab 5.1, ecoinvent v2.2 report 7, part XI, for Flat glass composition. Coating: 50% Ni, 50% Cr (ecoinvent v2.2 report 7, part XI, pg 18)',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Tab 5.1, ecoinvent v2.2 report 7, part XI, for Flat glass composition. Coating: 50% Ni, 50% Cr (ecoinvent v2.2 report 7, part XI, pg 18)',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 3.93e-06,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '37114: Glass in sheets, bent, edge-worked, engraved, drilled, enamelled or otherwise worked, but not framed, etc.',
#     'HS2017': '7005: Glass; float glass and surface ground or polished glass, in sheets, whether or not having an absorbent, refle[...]'},
#    'link': {'url': '21772',
#     'name': 'market for flat glass, coated',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'hydrogen, gaseous, medium pressure, merchant',
#    'group': 'From technosphere',
#    'comment': 'Estimation. Gas use in the power plant.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 9.25e-06,
#      'mu': -11.59088700643994,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'H2',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'H2',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'LHV is calculated based on the elemental composition of the substance. Based on the CAS number of the substance (001333-74-0), the chemical formula of the substance is found to be: H2, (PubChem 2020).\nReference: Kim, S., Chen, J., Cheng, T., Gindulyte, A., He, J., He, S., Li, Q., Shoemaker, B. A., Thiessen, P. A., Yu, B., Zaslavsky, L., Zhang, J., & Bolton, E. E. (2019). PubChem 2019 update: improved access to chemical data. Nucleic acids research, 47(D1), D1102–D1109. https://doi.org/10.1093/nar/gky1033',
#      'amount': 120.21},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 9.25e-06,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34210: Hydrogen, nitrogen, oxygen, carbon dioxide and rare gases; inorganic oxygen compounds of non-metals n.e.c.',
#     'HS2017': '280410: Hydrogen'},
#    'link': {'url': '11124',
#     'name': 'market for hydrogen, gaseous, medium pressure, merchant',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'lubricating oil',
#    'group': 'From technosphere',
#    'comment': 'Operator information. Oil and fats for hydraulic systems and general lubricating use.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.46e-06,
#      'mu': -13.437074122244029,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.75},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.75},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Lubricating oil is produced from diesel. C-content/dry mass of fats and oils considered 75%, from: ecoinvent v2.2 report, n 15a, pg 40',
#      'amount': 0.75},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Lubricating oil is produced from diesel.',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'Literature value, Source: IPCC 2006, 2006 IPCC Guidelines for National Greenhouse Gas Inventories, Prepared by the National Greenhouse Gas Inventories Programme, Eggleston H.S., Buendia L., Miwa K., Ngara T. and Tanabe K. (eds). Published: IGES, Japan',
#      'amount': 40.2},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.46e-06,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '33380: Lubricants'},
#    'link': {'url': '18883',
#     'name': 'market for lubricating oil',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'nitrogen, liquid',
#    'group': 'From technosphere',
#    'comment': 'Estimation. Gas use in the power plant. Nitrogen use and use of forming gas (5-10% H2, 90-95% N2) are summed up in this exchange.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 5.55e-05,
#      'mu': -9.799127537211886,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'N2',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'N2',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 5.55e-05,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34210: Hydrogen, nitrogen, oxygen, carbon dioxide and rare gases; inorganic oxygen compounds of non-metals n.e.c.',
#     'HS2017': '280430: Nitrogen'},
#    'link': {'url': '10975',
#     'name': 'market for nitrogen, liquid',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'nuclear power plant, boiling water reactor 1000MW',
#    'group': 'From technosphere',
#    'comment': 'Estimation. Total net electricity over a lifetime: 3.46E11 kWh',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 2.89e-12,
#      'mu': -26.569764613804207,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0}],
#    'amount': 2.89e-12,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '53262: Power plants',
#     'HS2017': '840110: Nuclear reactors'},
#    'link': {'url': '5314',
#     'name': 'market for nuclear power plant, boiling water reactor 1000MW',
#     'geography': 'GLO'},
#    'unit': 'unit',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'oxygen, liquid',
#    'group': 'From technosphere',
#    'comment': 'Estimation. Gas use in the power plant.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.5e-05,
#      'mu': -11.107460356862065,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'O2',
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'O2',
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.5e-05,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '34210: Hydrogen, nitrogen, oxygen, carbon dioxide and rare gases; inorganic oxygen compounds of non-metals n.e.c.',
#     'HS2017': '280440: Oxygen'},
#    'link': {'url': '12031',
#     'name': 'market for oxygen, liquid',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'paper, woodfree, coated',
#    'group': 'From technosphere',
#    'comment': 'Operator information. Paper use in office. No other office materials have been considered.',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 5.78e-07,
#      'mu': -14.363691968274034,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.2710370925875655},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.2868117381879},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Fossil C content was calculated after fossil C contents of chemicals used in the production of the paper (in Tab 8.72 & 8.73 ecoinvent v2.2 report 11_III, part 8).',
#      'amount': 0.0590616578039},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Biogenic C content was calculated after biogenic C contents of chemicals used in the production of the paper (in Tab 8.72 & 8.73 ecoinvent v2.2 report 11_III, part 8). The cellulose content in 1 kg of paper (on a wet mas basis) was estimated as (1-chemical content), C content of cellulose was considered 0.44 kgC/kg dry mass (ecoinvent v2.2 report, n 15a, pg 40)',
#      'amount': 0.227750080384},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'wet mass-water mass',
#      'amount': 0.945},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'Assumed equal to "waste newspaper".',
#      'amount': 14.11},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0582010582011},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': 'Moisture of paper and carboard assumed to be between 4 and 7% (http://www.spectro.in/paper-definition.htm). An average content of 5.5% is therefore used',
#      'amount': 0.055},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 5.78e-07,
#    'classification': {'By-product classification': 'allocatable product',
#     'CPC': '32113: Mechanical wood pulp; semi-chemical wood pulp; pulps of fibrous cellulosic material other than wood',
#     'HS2017': '481013: Paper and paperboard; coated with kaolin or other inorganic substances, for printing & writing, graphics, c[...]'},
#    'link': {'url': '7451',
#     'name': 'market for paper, woodfree, coated',
#     'geography': 'RER'},
#    'unit': 'kg',
#    'productionVolumeComment': None,
#    'productionVolumeAmount': None},
#   {'name': 'reinforcing steel',
#    'group': 'From technosphere',
#    'comment': 'Operator information',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 7.7e-07,
#      'mu': -14.076875322098681,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.004},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.004},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'Mix of differently produced steels and hot rolling',
#      'amount': 0.004},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'heating value, net',
#      'unit': 'MJ',
#      'uncertainty': None,
#      'comment': 'Non combustible products are assumed to have an LHV equal to zero (0).',
#      'amount': 0.0},
#     {'name': 'water content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': 'water mass/dry mass',
#      'amount': 0.0},
#     {'name': 'water in wet mass',
# ...
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.0312,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '378784-67-9',
#    'unit': 'kBq'},
#   {'name': 'Xenon-133',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.407,
#      'mu': -0.8989420935395421,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.407,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '014932-42-4',
#    'unit': 'kBq'},
#   {'name': 'Xenon-133m',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.00107,
#      'mu': -6.840096630508322,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.00107,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '378784-91-9',
#    'unit': 'kBq'},
#   {'name': 'Xenon-135',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.255,
#      'mu': -1.3664917338237108,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.255,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '014995-62-1',
#    'unit': 'kBq'},
#   {'name': 'Xenon-135m',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.289,
#      'mu': -1.241328590869705,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.289,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '378784-92-0',
#    'unit': 'kBq'},
#   {'name': 'Xenon-137',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.00917,
#      'mu': -4.691817992713764,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.00917,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '014835-21-3',
#    'unit': 'kBq'},
#   {'name': 'Xenon-138',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.0683,
#      'mu': -2.6838455124053926,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.0683,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '015751-81-2',
#    'unit': 'kBq'},
#   {'name': 'Zinc-65',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 7.39e-08,
#      'mu': -16.420553008992254,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 7.39e-08,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '013982-39-3',
#    'unit': 'kBq'},
#   {'name': 'Zinc-65',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into water of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 0.000182,
#      'mu': -8.611503870887478,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 0.000182,
#    'compartment': 'water',
#    'sub_compartment': 'surface water',
#    'cas_number': '013982-39-3',
#    'unit': 'kBq'},
#   {'name': 'Zirconium-95',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into air of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 1.59e-09,
#      'mu': -20.259531820714272,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 1.59e-09,
#    'compartment': 'air',
#    'sub_compartment': 'non-urban air or from high stacks',
#    'cas_number': '013967-71-0',
#    'unit': 'kBq'},
#   {'name': 'Zirconium-95',
#    'group': 'To environment',
#    'comment': 'Operator data. Weighted radioactive emissions into water of Swiss nuclear power plants 1995-2002 (Weighting with net electricity production).',
#    'uncertainty': {'pedigreeMatrix': '[2, 2, 5, 5, 2]',
#     'comment': None,
#     'type': 'lognormal',
#     'value': {'meanValue': 2.78e-07,
#      'mu': -15.095644723255774,
#      'variance': 0.0006,
#      'varianceWithPedigreeUncertainty': 0.04390000000000001}},
#    'property': [{'name': 'carbon allocation',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'carbon content, non-fossil',
#      'unit': 'dimensionless',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'dry mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0},
#     {'name': 'water in wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 0.0},
#     {'name': 'wet mass',
#      'unit': 'kg',
#      'uncertainty': None,
#      'comment': None,
#      'amount': 1.0}],
#    'amount': 2.78e-07,
#    'compartment': 'water',
#    'sub_compartment': 'surface water',
#    'cas_number': '013967-71-0',
#    'unit': 'kBq'}]}

# %%
ep.get_impacts("1466")
# Out:
# [{'index': 1466,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'acidification',
#   'indicator_name': 'accumulated exceedance (AE)',
#   'amount': 5.8746036995846155e-05,
#   'unit_name': 'mol H+-Eq'},
#  {'index': 1467,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'climate change',
#   'indicator_name': 'global warming potential (GWP100)',
#   'amount': 0.00766858172590214,
#   'unit_name': 'kg CO2-Eq'},
#  {'index': 1468,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'climate change: biogenic',
#   'indicator_name': 'global warming potential (GWP100)',
#   'amount': 2.8608711173290143e-05,
#   'unit_name': 'kg CO2-Eq'},
#  {'index': 1469,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'climate change: fossil',
#   'indicator_name': 'global warming potential (GWP100)',
#   'amount': 0.007624757482921802,
#   'unit_name': 'kg CO2-Eq'},
#  {'index': 1538,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'climate change: GHG (EPD PCR)',
#   'indicator_name': 'global warming potential (GWP100)',
#   'amount': 0.007660433387291134,
#   'unit_name': 'kg CO2-Eq'},
#  {'index': 1470,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'climate change: land use and land use change',
#   'indicator_name': 'global warming potential (GWP100)',
#   'amount': 1.5215531807048342e-05,
#   'unit_name': 'kg CO2-Eq'},
#  {'index': 1471,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'ecotoxicity: freshwater',
#   'indicator_name': 'comparative toxic unit for ecosystems (CTUe)',
#   'amount': 0.06681429440366658,
#   'unit_name': 'CTUe'},
#  {'index': 1472,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'energy resources: non-renewable',
#   'indicator_name': 'abiotic depletion potential (ADP): fossil fuels',
#   'amount': 14.059540222979711,
#   'unit_name': 'MJ, net calorific value'},
#  {'index': 1473,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'eutrophication: freshwater',
#   'indicator_name': 'fraction of nutrients reaching freshwater end compartment (P)',
#   'amount': 4.271258719770312e-06,
#   'unit_name': 'kg P-Eq'},
#  {'index': 1474,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'eutrophication: marine',
#   'indicator_name': 'fraction of nutrients reaching marine end compartment (N)',
#   'amount': 5.9081314782933686e-05,
#   'unit_name': 'kg N-Eq'},
#  {'index': 1475,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'eutrophication: terrestrial',
#   'indicator_name': 'accumulated exceedance (AE)',
#   'amount': 0.00016453075186329436,
#   'unit_name': 'mol N-Eq'},
#  {'index': 1476,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'human toxicity: carcinogenic',
#   'indicator_name': 'comparative toxic unit for human (CTUh)',
#   'amount': 6.146415712955216e-12,
#   'unit_name': 'CTUh'},
#  {'index': 1477,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'human toxicity: non-carcinogenic',
#   'indicator_name': 'comparative toxic unit for human (CTUh)',
#   'amount': 3.204404079677996e-10,
#   'unit_name': 'CTUh'},
#  {'index': 1478,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'ionising radiation: human health',
#   'indicator_name': 'human exposure efficiency relative to u235',
#   'amount': 1.178514991712068,
#   'unit_name': 'kBq U235-Eq'},
#  {'index': 1479,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'land use',
#   'indicator_name': 'soil quality index',
#   'amount': 0.04586347870116003,
#   'unit_name': 'dimensionless'},
#  {'index': 1480,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'material resources: metals/minerals',
#   'indicator_name': 'abiotic depletion potential (ADP): elements (ultimate reserves)',
#   'amount': 1.272785896215952e-07,
#   'unit_name': 'kg Sb-Eq'},
#  {'index': 1481,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'ozone depletion',
#   'indicator_name': 'ozone depletion potential (ODP)',
#   'amount': 2.6931827254081093e-10,
#   'unit_name': 'kg CFC-11-Eq'},
#  {'index': 1482,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'particulate matter formation',
#   'indicator_name': 'impact on human health',
#   'amount': 3.6289198710844854e-09,
#   'unit_name': 'disease incidence'},
#  {'index': 1483,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'photochemical oxidant formation: human health',
#   'indicator_name': 'tropospheric ozone concentration increase',
#   'amount': 5.016987543428112e-05,
#   'unit_name': 'kg NMVOC-Eq'},
#  {'index': 1484,
#   'method_name': 'EF v3.1 EN15804',
#   'category_name': 'water use',
#   'indicator_name': 'user deprivation potential (deprivation-weighted water consumption)',
#   'amount': 0.13333264669388675,
#   'unit_name': 'm3 world Eq deprived'}]

# %%
ep.get_direct_contributions("1479")
# Out:
# {'total_score': 0.04586347870116003,
#  'direct_contributions': [{'type': 'product',
#    'amount': 2.68e-06,
#    'unit': 'kg',
#    'factor': 7279.875443316591,
#    'impact': 0.019510066188088464,
#    'relative_contribution': 0.42539438221015263,
#    'meta': {'name': 'market for uranium, enriched 3.8%, in fuel element for light water reactor',
#     'comp': 'GLO',
#     'subcomp': 'uranium, enriched 3.8%, in fuel element for light water reactor'},
#    'index': 3046},
#   {'type': 'product',
#    'amount': 2.89e-12,
#    'unit': 'unit',
#    'factor': 5627670016.624977,
#    'impact': 0.016263966348046183,
#    'relative_contribution': 0.3546169372371402,
#    'meta': {'name': 'market for nuclear power plant, boiling water reactor 1000MW',
#     'comp': 'GLO',
#     'subcomp': 'nuclear power plant, boiling water reactor 1000MW'},
#    'index': 5314},
#   {'type': 'product',
#    'amount': -2.68e-06,
#    'unit': 'kg',
#    'factor': 1775.7017107716526,
#    'impact': 0.004758880584868029,
#    'relative_contribution': 0.10376187588988234,
#    'meta': {'name': 'market for spent nuclear fuel',
#     'comp': 'GLO',
#     'subcomp': 'spent nuclear fuel'},
#    'index': 4865},
#   {'type': 'product',
#    'amount': 3.28120231213873,
#    'unit': 'kg',
#    'factor': 0.0008299040669633524,
#    'impact': 0.0027230831433734874,
#    'relative_contribution': 0.05937367204779022,
#    'meta': {'name': 'market for water, decarbonised',
#     'comp': 'RoW',
#     'subcomp': 'water, decarbonised'},
#    'index': 19487},
#   {'type': 'product',
#    'amount': -1.6568e-08,
#    'unit': 'm3',
#    'factor': 83413.79515961414,
#    'impact': 0.001381999758204487,
#    'relative_contribution': 0.030132903071077594,
#    'meta': {'name': 'market for low level radioactive waste',
#     'comp': 'GLO',
#     'subcomp': 'low level radioactive waste'},
#    'index': 7950},
#   {'type': 'product',
#    'amount': -4.05e-08,
#    'unit': 'm3',
#    'factor': 19042.420359167176,
#    'impact': 0.0007712180245462706,
#    'relative_contribution': 0.016815515228825503,
#    'meta': {'name': 'market for low level radioactive waste for final repository',
#     'comp': 'GLO',
#     'subcomp': 'low level radioactive waste for final repository'},
#    'index': 695},
#   {'type': 'product',
#    'amount': 2.34e-05,
#    'unit': 'kg',
#    'factor': 4.671839724185514,
#    'impact': 0.00010932104954594102,
#    'relative_contribution': 0.0023836187886719534,
#    'meta': {'name': 'market for argon, liquid',
#     'comp': 'RER',
#     'subcomp': 'argon, liquid'},
#    'index': 18958},
#   {'type': 'product',
#    'amount': 5.78e-07,
#    'unit': 'kg',
#    'factor': 136.483351586589,
#    'impact': 7.888737721704846e-05,
#    'relative_contribution': 0.0017200478343796705,
#    'meta': {'name': 'market for paper, woodfree, coated',
#     'comp': 'RER',
#     'subcomp': 'paper, woodfree, coated'},
#    'index': 7451},
#   {'type': 'product',
#    'amount': 5.55e-05,
#    'unit': 'kg',
#    'factor': 0.7842276424582659,
#    'impact': 4.352463415643376e-05,
#    'relative_contribution': 0.0009490042052857382,
#    'meta': {'name': 'market for nitrogen, liquid',
#     'comp': 'RER',
#     'subcomp': 'nitrogen, liquid'},
#    'index': 10975},
#   {'type': 'product',
#    'amount': 5.4e-06,
#    'unit': 'kg',
#    'factor': 7.327992668990895,
#    'impact': 3.9571160412550835e-05,
#    'relative_contribution': 0.0008628032921442994,
#    'meta': {'name': 'market for steel, low-alloyed, hot rolled',
#     'comp': 'GLO',
#     'subcomp': 'steel, low-alloyed, hot rolled'},
#    'index': 7677},
#   {'type': 'product',
#    'amount': 9.25e-06,
#    'unit': 'kg',
#    'factor': 3.495745031238851,
#    'impact': 3.233564153895937e-05,
#    'relative_contribution': 0.0007050411886471555,
#    'meta': {'name': 'market for hydrogen, gaseous, medium pressure, merchant',
#     'comp': 'RER',
#     'subcomp': 'hydrogen, gaseous, medium pressure, merchant'},
#    'index': 11124},
#   {'type': 'product',
#    'amount': 1.5e-05,
#    'unit': 'kg',
#    'factor': 1.904391003320879,
#    'impact': 2.8565865049813186e-05,
#    'relative_contribution': 0.0006228455812509195,
#    'meta': {'name': 'market for oxygen, liquid',
#     'comp': 'RER',
#     'subcomp': 'oxygen, liquid'},
#    'index': 12031},
#   {'type': 'product',
#    'amount': 1.59e-08,
#    'unit': 'm3',
#    'factor': 1688.5595617562165,
#    'impact': 2.684809703192384e-05,
#    'relative_contribution': 0.0005853916404131109,
#    'meta': {'name': 'market for concrete, normal strength',
#     'comp': 'RoW',
#     'subcomp': 'concrete, normal strength'},
#    'index': 12483},
#   {'type': 'product',
#    'amount': 0.000333,
#    'unit': 'MJ',
#    'factor': 0.07878698433318009,
#    'impact': 2.623606578294897e-05,
#    'relative_contribution': 0.000572047008337494,
#    'meta': {'name': 'market for diesel, burned in diesel-electric generating set, 10MW',
#     'comp': 'GLO',
#     'subcomp': 'diesel, burned in diesel-electric generating set, 10MW'},
#    'index': 6946},
#   {'type': 'product',
#    'amount': 3.93e-06,
#    'unit': 'kg',
#    'factor': 4.649627458172455,
#    'impact': 1.8273035910617747e-05,
#    'relative_contribution': 0.00039842237065535905,
#    'meta': {'name': 'market for flat glass, coated',
#     'comp': 'RER',
#     'subcomp': 'flat glass, coated'},
#    'index': 21772},
#   {'type': 'product',
#    'amount': 1.46e-06,
#    'unit': 'kg',
#    'factor': 6.392303134287829,
#    'impact': 9.33276257606023e-06,
#    'relative_contribution': 0.00020349007184717054,
#    'meta': {'name': 'market for lubricating oil',
#     'comp': 'RER',
#     'subcomp': 'lubricating oil'},
#    'index': 18883},
#   {'type': 'product',
#    'amount': 1.24e-06,
#    'unit': 'kg',
#    'factor': 7.514635038613293,
#    'impact': 9.318147447880484e-06,
#    'relative_contribution': 0.00020317140591528653,
#    'meta': {'name': 'market for chemical, organic',
#     'comp': 'GLO',
#     'subcomp': 'chemical, organic'},
#    'index': 7063},
#   {'type': 'product',
#    'amount': 7.71e-06,
#    'unit': 'kg',
#    'factor': 0.8689930752175188,
#    'impact': 6.69993660992707e-06,
#    'relative_contribution': 0.00014608435294633697,
#    'meta': {'name': 'market for cement, Portland',
#     'comp': 'Europe without Switzerland',
#     'subcomp': 'cement, Portland'},
#    'index': 324},
#   {'type': 'product',
#    'amount': 6.01e-07,
#    'unit': 'kg',
#    'factor': 9.368906565068475,
#    'impact': 5.630712845606154e-06,
#    'relative_contribution': 0.00012277116793287936,
#    'meta': {'name': 'market for chemical, inorganic',
#     'comp': 'GLO',
#     'subcomp': 'chemical, inorganic'},
#    'index': 4588},
#   {'type': 'product',
#    'amount': 7.7e-07,
#    'unit': 'kg',
#    'factor': 6.511881768440816,
#    'impact': 5.014148961699428e-06,
#    'relative_contribution': 0.00010932770700563114,
#    'meta': {'name': 'market for reinforcing steel',
#     'comp': 'GLO',
#     'subcomp': 'reinforcing steel'},
#    'index': 5731},
#   {'type': 'product',
#    'amount': 1.06e-06,
#    'unit': 'kg',
#    'factor': 4.625484840702764,
#    'impact': 4.903013931144929e-06,
#    'relative_contribution': 0.00010690453646336506,
#    'meta': {'name': 'market for anionic resin',
#     'comp': 'RER',
#     'subcomp': 'anionic resin'},
#    'index': 18488},
#   {'type': 'product',
#    'amount': -1.97e-06,
#    'unit': 'kg',
#    'factor': 1.8990943257079922,
#    'impact': 3.741215821644745e-06,
#    'relative_contribution': 8.157287514150378e-05,
#    'meta': {'name': 'market for fly ash and scrubber sludge',
#     'comp': 'Europe without Switzerland',
#     'subcomp': 'fly ash and scrubber sludge'},
#    'index': 15433},
#   {'type': 'product',
#    'amount': 1.06e-06,
#    'unit': 'kg',
#    'factor': 2.1751711199917163,
#    'impact': 2.3056813871912195e-06,
#    'relative_contribution': 5.027271049836221e-05,
#    'meta': {'name': 'market for cationic resin',
#     'comp': 'RER',
#     'subcomp': 'cationic resin'},
#    'index': 18700},
#   {'type': 'product',
#    'amount': -8.73e-07,
#    'unit': 'kg',
#    'factor': 2.241376407199004,
#    'impact': 1.9567216034847307e-06,
#    'relative_contribution': 4.266404683854125e-05,
#    'meta': {'name': 'market for hazardous waste, for incineration',
#     'comp': 'Europe without Switzerland',
#     'subcomp': 'hazardous waste, for incineration'},
#    'index': 15759},
#   {'type': 'product',
#    'amount': 1.16e-07,
#    'unit': 'kg',
#    'factor': 4.973771686850187,
#    'impact': 5.769575156746217e-07,
#    'relative_contribution': 1.2579889969402357e-05,
#    'meta': {'name': 'market for cast iron',
#     'comp': 'GLO',
#     'subcomp': 'cast iron'},
#    'index': 2023},
#   {'type': 'product',
#    'amount': 3.24e-08,
#    'unit': 'kg',
#    'factor': 11.050805530037096,
#    'impact': 3.5804609917320187e-07,
#    'relative_contribution': 7.806780238066541e-06,
#    'meta': {'name': 'market for acetylene',
#     'comp': 'RER',
#     'subcomp': 'acetylene'},
#    'index': 17738},
#   {'type': 'product',
#    'amount': 1.5e-07,
#    'unit': 'kg',
#    'factor': 1.853324659778803,
#    'impact': 2.779986989668204e-07,
#    'relative_contribution': 6.061439446802995e-06,
#    'meta': {'name': 'market for carbon dioxide, liquid',
#     'comp': 'RER',
#     'subcomp': 'carbon dioxide, liquid'},
#    'index': 12080},
#   {'type': 'product',
#    'amount': 2.31e-08,
#    'unit': 'kg',
#    'factor': 9.96027205427896,
#    'impact': 2.3008228445384397e-07,
#    'relative_contribution': 5.016677560658399e-06,
#    'meta': {'name': 'market for boric acid, anhydrous, powder',
#     'comp': 'GLO',
#     'subcomp': 'boric acid, anhydrous, powder'},
#    'index': 2292},
#   {'type': 'product',
#    'amount': 2.89e-08,
#    'unit': 'kg',
#    'factor': 6.67593644339948,
#    'impact': 1.9293456321424497e-07,
#    'relative_contribution': 4.206714551056613e-06,
#    'meta': {'name': 'market for borax, anhydrous, powder',
#     'comp': 'GLO',
#     'subcomp': 'borax, anhydrous, powder'},
#    'index': 5073},
#   {'type': 'product',
#    'amount': -1.46e-06,
#    'unit': 'kg',
#    'factor': 0.11189521982536091,
#    'impact': 1.6336702094502693e-07,
#    'relative_contribution': 3.5620285589216515e-06,
#    'meta': {'name': 'market for waste mineral oil',
#     'comp': 'Europe without Switzerland',
#     'subcomp': 'waste mineral oil'},
#    'index': 15332}]}

# %%
mas = ei.ImpactIndexMapper(ep)

# %%
# mas.scan_range(1463, 1500)

# %%
7957
# Out:
# 7957

# %%
ep.searcher('steel')
# Out:
# {'hits': {'total': {'value': 437, 'relation': 'eq'},
#   'hits': [{'_score': 30.301262,
#     '_source': {'activity_name': 'steel production, electric, chromium steel 18/8',
#      'product_name': 'steel, chromium steel 18/8',
#      'unit_name': 'kg',
#      'geography_shortname': 'RER',
#      'geography_longname': 'Europe',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 1482}},
#    {'_score': 30.301262,
#     '_source': {'activity_name': 'steel production, electric, chromium steel 18/8',
#      'product_name': 'steel, chromium steel 18/8',
#      'unit_name': 'kg',
#      'geography_shortname': 'RoW',
#      'geography_longname': 'Rest-of-World',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 9586}},
#    {'_score': 30.078426,
#     '_source': {'activity_name': 'steel production, chromium steel 18/8, hot rolled',
#      'product_name': 'steel, chromium steel 18/8, hot rolled',
#      'unit_name': 'kg',
#      'geography_shortname': 'RER',
#      'geography_longname': 'Europe',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 1100}},
#    {'_score': 30.078426,
#     '_source': {'activity_name': 'steel production, chromium steel 18/8, hot rolled',
#      'product_name': 'steel, chromium steel 18/8, hot rolled',
#      'unit_name': 'kg',
#      'geography_shortname': 'RoW',
#      'geography_longname': 'Rest-of-World',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 614}},
#    {'_score': 30.065739,
#     '_source': {'activity_name': 'steel drilling, conventional',
#      'product_name': 'steel removed by drilling, conventional',
#      'unit_name': 'kg',
#      'geography_shortname': 'RER',
#      'geography_longname': 'Europe',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 9553}},
#    {'_score': 30.065739,
#     '_source': {'activity_name': 'steel drilling, conventional',
#      'product_name': 'steel removed by drilling, conventional',
#      'unit_name': 'kg',
#      'geography_shortname': 'RoW',
#      'geography_longname': 'Rest-of-World',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 7208}},
#    {'_score': 30.065739,
#     '_source': {'activity_name': 'steel milling, average',
#      'product_name': 'steel removed by milling, average',
#      'unit_name': 'kg',
#      'geography_shortname': 'RER',
#      'geography_longname': 'Europe',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 3380}},
#    {'_score': 30.065739,
#     '_source': {'activity_name': 'steel milling, average',
#      'product_name': 'steel removed by milling, average',
#      'unit_name': 'kg',
#      'geography_shortname': 'RoW',
#      'geography_longname': 'Rest-of-World',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 7018}},
#    {'_score': 30.065739,
#     '_source': {'activity_name': 'steel milling, dressing',
#      'product_name': 'steel removed by milling, dressing',
#      'unit_name': 'kg',
#      'geography_shortname': 'RER',
#      'geography_longname': 'Europe',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 7434}},
#    {'_score': 30.065739,
#     '_source': {'activity_name': 'steel milling, dressing',
#      'product_name': 'steel removed by milling, dressing',
#      'unit_name': 'kg',
#      'geography_shortname': 'RoW',
#      'geography_longname': 'Rest-of-World',
#      'sector': ['Metals'],
#      'activity_type': 'TRANSFORMING_ACTIVITY',
#      'spold_id': 1294}}]},
#  'aggregations': {'isic_section': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': 'C - Manufacturing', 'doc_count': 310},
#     {'key': 'E - Water supply; sewerage, waste management and remediation activities',
#      'doc_count': 69},
#     {'key': 'A - Agriculture, forestry and fishing', 'doc_count': 31},
#     {'key': 'F - Construction', 'doc_count': 27}]},
#   'geography': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': 'Rest-of-World (RoW)', 'doc_count': 145},
#     {'key': 'Global (GLO)', 'doc_count': 124},
#     {'key': 'Europe (RER)', 'doc_count': 84},
#     {'key': 'Switzerland (CH)', 'doc_count': 47},
#     {'key': 'Austria (AT)', 'doc_count': 7},
#     {'key': 'Canada, Québec (CA-QC)', 'doc_count': 6},
#     {'key': 'Europe without Switzerland (Europe without Switzerland)',
#      'doc_count': 5},
#     {'key': 'Peru (PE)', 'doc_count': 4},
#     {'key': 'Brazil (BR)', 'doc_count': 3},
#     {'key': 'Latin America and the Caribbean (RLA)', 'doc_count': 3},
#     {'key': 'Canada (CA)', 'doc_count': 2},
#     {'key': 'Europe without Austria (Europe without Austria)', 'doc_count': 2},
#     {'key': 'India (IN)', 'doc_count': 2},
#     {'key': 'Spain (ES)', 'doc_count': 2},
#     {'key': 'Europe without Switzerland and Austria (Europe without Switzerland and Austria)',
#      'doc_count': 1}]},
#   'cpc': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': []},
#   'activity_type': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': 'TRANSFORMING_ACTIVITY', 'doc_count': 293},
#     {'key': 'MARKET_ACTIVITY', 'doc_count': 144}]},
#   'sector': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': 'Metals', 'doc_count': 281},
#     {'key': 'Infrastructure & Machinery', 'doc_count': 100},
#     {'key': 'Waste Treatment & Recycling', 'doc_count': 77},
#     {'key': 'Fishing & Aquaculture', 'doc_count': 31},
#     {'key': 'Electricity', 'doc_count': 6},
#     {'key': 'Heat', 'doc_count': 6},
#     {'key': 'Cement & Concrete', 'doc_count': 4}]},
#   'isic_class': {'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 0,
#    'buckets': [{'key': '2592:Treatment and coating of metals; machining',
#      'doc_count': 94},
#     {'key': '2591:Forging, pressing, stamping and roll-forming of metal; powder metallurgy',
#      'doc_count': 93},
#     {'key': '2410:Manufacture of basic iron and steel', 'doc_count': 60},
#     {'key': '2819:Manufacture of other general-purpose machinery',
#      'doc_count': 42},
#     {'key': '3830:Materials recovery', 'doc_count': 34},
#     {'key': '0311:Marine fishing', 'doc_count': 31},
#     {'key': '3821:Treatment and disposal of non-hazardous waste',
#      'doc_count': 30},
#     {'key': '4322:Plumbing, heat and air-conditioning installation',
#      'doc_count': 21},
#     {'key': '2599:Manufacture of other fabricated metal products n.e.c.',
#      'doc_count': 8},
#     {'key': '259:Manufacture of other fabricated metal products; metalworking service activit',
#      'doc_count': 6},
#     {'key': '3822:Treatment and disposal of hazardous waste', 'doc_count': 5},
#     {'key': '2431:Casting of iron and steel', 'doc_count': 3},
#     {'key': '4100:Construction of buildings', 'doc_count': 3},
#     {'key': '4312:Site preparation', 'doc_count': 3},
#     {'key': '2394:Manufacture of cement, lime and plaster', 'doc_count': 2},
#     {'key': '2395:Manufacture of articles of concrete, cement and plaster',
#      'doc_count': 2}]}}}
